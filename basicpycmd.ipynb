# %% [markdown]
# <a href="https://colab.research.google.com/github/nandainf-blip/python-genai-anand/blob/main/basicpycmd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a="hello"
print("".join(reversed(a)))
print(a[::-1])


def reverse_string(s):
  if len(s) == 0:
     return s
  else:
      return reverse_string(s[1:]) + s[0]

print(reverse_string("Hello World"))
print(type(a))
# while loop
a=0
while a < 5:
    print("iteration",a)
    a = a + 1

# get input, type cast and add
a1 = int(input("enter a number"))
a2 = int(input("enter second number"))
print("add", a1 + a2)
# Out:
# olleh
# olleh
# dlroW olleH
# <class 'str'>
# iteration 0
# iteration 1
# iteration 2
# iteration 3
# iteration 4
# enter a number3
# enter second number2
# add 5

# %%
# list functions
print(type(reverse_string))

list1 = ["komal","sing","june","jul"]
print(list1[::-2])
print("pop fn:",list1.pop(3))
print(type(a2))
print("july" in list1)
list1.insert(1,"jack")
list1.sort(reverse = True)
print(list1)
list1.sort()
print(list1)
list1.reverse()
print(list1)
# Out:
# <class 'function'>
# ['jul', 'sing']
# pop fn: jul
# <class 'int'>
# False
# ['sing', 'komal', 'june', 'jack']
# ['jack', 'june', 'komal', 'sing']
# ['sing', 'komal', 'june', 'jack']

# %%
# function

def greet(name="guest", age=40):
  return ("Hello " + name)

print(greet("Anand", 43))
print(greet())

a=[1,2,3,4,5,6,6,7,7,8]
print(type(a))
print(a)
b = set(a)
print("typeconv",b)
print(type(b))
b=a.copy()
print(b)
print(type(b))
print(type(a))
# Out:
# Hello Anand
# Hello guest
# <class 'list'>
# [1, 2, 3, 4, 5, 6, 6, 7, 7, 8]
# typeconv {1, 2, 3, 4, 5, 6, 7, 8}
# <class 'set'>
# [1, 2, 3, 4, 5, 6, 6, 7, 7, 8]
# <class 'list'>
# <class 'list'>
